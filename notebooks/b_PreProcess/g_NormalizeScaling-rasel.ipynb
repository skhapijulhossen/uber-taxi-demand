# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading data

# %%
data = pd.read_parquet(r"C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/data/2022/V4_FeatureSelection_Data.parquet")
data.head()
# Out:
#             timestamp  taxi_demand  timestamp_quarter_end  \
# 0 2022-04-01 15:00:00         8487                      0
# 1 2022-04-01 16:00:00         7888                      0
# 2 2022-04-01 17:00:00         9788                      0
# 3 2022-04-01 18:00:00        10527                      0
# 4 2022-04-01 19:00:00         9697                      0
#
#    timestamp_year_start  timestamp_leap_year  timestamp_hour  \
# 0                     0                    0              15
# 1                     0                    0              16
# 2                     0                    0              17
# 3                     0                    0              18
# 4                     0                    0              19
#
#    timestamp_days_in_month  passenger_demand_expanding_std  \
# 0                       30                     3823.294951
# 1                       30                     4127.546522
# 2                       30                     4301.369187
# ...

# %%
# sns.pairplot(data = data )

# %%
df = data.copy()

# %% [markdown]
# # Need to Standardize to Noemal/STD Normal Distribution

# %%
df2 = df.drop(columns=["timestamp"])
mean = np.mean(df2)
mean
# Out:
# 1127.1078971668942

# %%
std_dev = np.std(df2)
std_dev
# Out:
# C:\Users\SRA\Desktop\backup\C\MLgrit\time_series_project\timeseriesENV\lib\site-packages\numpy\core\fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# taxi_demand                       2879.949842
# timestamp_quarter_end                0.085390
# timestamp_year_start                 0.052411
# timestamp_leap_year                  0.000000
# timestamp_hour                       6.922886
# timestamp_days_in_month              0.842100
# passenger_demand_expanding_std     148.428710
# timestamp_day_of_week                2.002322
# taxi_demand_lag_1                 2879.985085
# timestamp_day_of_month               8.749852
# timestamp_second                     0.000000
# passenger_demand_lag_8            4051.795459
# ...

# %%
df2.head()
# Out:
#    taxi_demand  timestamp_quarter_end  timestamp_year_start  \
# 0         8487                      0                     0
# 1         7888                      0                     0
# 2         9788                      0                     0
# 3        10527                      0                     0
# 4         9697                      0                     0
#
#    timestamp_leap_year  timestamp_hour  timestamp_days_in_month  \
# 0                    0              15                       30
# 1                    0              16                       30
# 2                    0              17                       30
# 3                    0              18                       30
# 4                    0              19                       30
#
#    passenger_demand_expanding_std  timestamp_day_of_week  taxi_demand_lag_1  \
# 0                     3823.294951                      4             7792.0
# ...

# %%
# standardized_scores = [(x - mean) / std_dev for x in df2]
# z = (x - u) / s

# %%
# StandardScaler?

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
scaler = StandardScaler()
scaler.fit(df2.drop(columns='taxi_demand'))
# Out:
# StandardScaler()

# %%
df2.loc[:, df2.columns[:-1]] = scaler.transform(df2.drop(columns='taxi_demand'))
df2.head()
# Out:
#    taxi_demand  timestamp_quarter_end  timestamp_year_start  \
# 0    -0.052556                    0.0              0.505760
# 1    -0.052556                    0.0              0.650209
# 2    -0.052556                    0.0              0.794657
# 3    -0.052556                    0.0              0.939105
# 4    -0.052556                    0.0              1.083554
#
#    timestamp_leap_year  timestamp_hour  timestamp_days_in_month  \
# 0            -0.522269       -1.208005                 0.500165
# 1            -0.522269        0.841812                 0.500165
# 2            -0.522269        2.012897                 0.500165
# 3            -0.522269        4.058447                 0.500165
# 4            -0.522269        6.209444                 0.500165
#
#    passenger_demand_expanding_std  timestamp_day_of_week  taxi_demand_lag_1  \
# 0                        1.794973               -1.67886                0.0
# ...

# %%
# sns.pairplot(data = df2)

# %%
scaler.mean_
# Out:
# array([7.34534603e-03, 2.75450476e-03, 0.00000000e+00, 1.14986801e+01,
#        3.04398026e+01, 4.00259752e+03, 2.99850798e+00, 2.62250522e+03,
#        1.56897739e+01, 0.00000000e+00, 3.67614989e+03, 1.82774016e+02,
#        3.13324917e-02, 0.00000000e+00, 1.14771032e-04, 2.02200000e+03,
#        3.67637186e+03, 2.93813841e-02, 3.67657649e+03])

# %%
scaler
# Out:
# StandardScaler()

# %%
# Lets save our Train data

# %%
df2.to_parquet(r"C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/data/2022/V5_NormalizeScaling_trainData.parquet", index=False)
