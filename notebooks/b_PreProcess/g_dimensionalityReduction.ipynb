# %%
import numpy as np
import pandas as pd
from feature_engine.datetime import DatetimeFeatures

# %%
data = pd.read_parquet(
    'd:/uber-taxi-demand/data/yellow_trip_features_v4.parquet'
)

# %%
data.head().T
# Out:
#                                                  0                    1  \
# timestamp                      2022-01-02 00:00:00  2022-01-02 01:00:00
# taxiDemand                                    1483                 1016
# timestamp_day_of_week                            6                    6
# passengerDemand_window_7_std           1132.856188          1264.258469
# passengerDemand_expanding_std          1926.172935          1920.277885
# passengerDemand_lag_8                       5754.0               5881.0
# passengerDemand_lag_24                      6838.0               7738.0
# timestamp_year_start                             0                    0
# timestamp_month_end                              0                    0
# passengerDemand_lag_1                       2798.0               2288.0
# timestamp_day_of_month                           2                    2
# timestamp_month_start                            0                    0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8713 entries, 0 to 8712
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   timestamp                      8713 non-null   datetime64[ns]
#  1   taxiDemand                     8713 non-null   int64
#  2   timestamp_day_of_week          8713 non-null   int32
#  3   passengerDemand_window_7_std   8713 non-null   float64
#  4   passengerDemand_expanding_std  8713 non-null   float64
#  5   passengerDemand_lag_8          8713 non-null   float64
#  6   passengerDemand_lag_24         8713 non-null   float64
#  7   timestamp_year_start           8713 non-null   int64
#  8   timestamp_month_end            8713 non-null   int64
#  9   passengerDemand_lag_1          8713 non-null   float64
#  10  timestamp_day_of_month         8713 non-null   int32
#  11  timestamp_month_start          8713 non-null   int64
# ...

# %%
df = data.copy()

# %% [markdown]
# <center><b>PCA</b></center>
