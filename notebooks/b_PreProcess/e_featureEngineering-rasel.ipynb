# %% [markdown]
# # Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from feature_engine.datetime import DatetimeFeatures
from feature_engine.timeseries.forecasting import LagFeatures, WindowFeatures, ExpandingWindowFeatures

# %matplotlib inline

# %% [markdown]
# # Loading Data

# %%
data = pd.read_parquet(r"C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/data/2022/V2_Clean_Data.parquet")
data.head()
# Out:
#    passenger_demand  taxi_demand           timestamp
# 0                 4            4 2022-03-31 15:00:00
# 1                 3            3 2022-03-31 16:00:00
# 2                 0            0 2022-03-31 17:00:00
# 3                 0            0 2022-03-31 18:00:00
# 4                 0            0 2022-03-31 19:00:00

# %%
data
# Out:
#       passenger_demand  taxi_demand           timestamp
# 0                    4            4 2022-03-31 15:00:00
# 1                    3            3 2022-03-31 16:00:00
# 2                    0            0 2022-03-31 17:00:00
# 3                    0            0 2022-03-31 18:00:00
# 4                    0            0 2022-03-31 19:00:00
# ...                ...          ...                 ...
# 8732              8489         6242 2022-05-31 11:00:00
# 8733              8714         6444 2022-05-31 12:00:00
# 8734              9389         6915 2022-05-31 13:00:00
# 8735              9997         7296 2022-05-31 14:00:00
# 8736             10589         7618 2022-05-31 15:00:00
#
# [8737 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8737 entries, 0 to 8736
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   passenger_demand  8737 non-null   int64
#  1   taxi_demand       8737 non-null   int64
#  2   timestamp         8737 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 204.9 KB

# %%
df = data.copy()

# %%
# df.set_index('timestamp', inplace=True)

# %%
df
# Out:
#       passenger_demand  taxi_demand           timestamp
# 0                    4            4 2022-03-31 15:00:00
# 1                    3            3 2022-03-31 16:00:00
# 2                    0            0 2022-03-31 17:00:00
# 3                    0            0 2022-03-31 18:00:00
# 4                    0            0 2022-03-31 19:00:00
# ...                ...          ...                 ...
# 8732              8489         6242 2022-05-31 11:00:00
# 8733              8714         6444 2022-05-31 12:00:00
# 8734              9389         6915 2022-05-31 13:00:00
# 8735              9997         7296 2022-05-31 14:00:00
# 8736             10589         7618 2022-05-31 15:00:00
#
# [8737 rows x 3 columns]

# %% [markdown]
# # Add Temporal Features

# %%
# DatetimeFeatures?

# %%
def add_temporal_features(df: pd.DataFrame) -> pd.DataFrame:
    features_to_extract = [
        "month", "quarter","semester","year","week","day_of_week","day_of_month",
        "day_of_year","weekend","month_start","month_end","quarter_start",
        "quarter_end","year_start","year_end","leap_year","days_in_month","hour","minute","second"
    ]
        
    ###
    temporal = DatetimeFeatures(features_to_extract = features_to_extract).fit_transform(df[['timestamp']])
    for col in temporal.columns:
        df.loc[:,col] = temporal[col].values

# %%
features_to_extract = [
    "month", "quarter","semester","year","week","day_of_week","day_of_month",
    "day_of_year","weekend","month_start","month_end","quarter_start",
    "quarter_end","year_start","year_end","leap_year","days_in_month","hour","minute","second"]

# %%
temporal = DatetimeFeatures(
    features_to_extract=features_to_extract).fit_transform(df[['timestamp']])
temporal.head()
# Out:
#    timestamp_month  timestamp_quarter  timestamp_semester  timestamp_year  \
# 0                3                  1                   1            2022
# 1                3                  1                   1            2022
# 2                3                  1                   1            2022
# 3                3                  1                   1            2022
# 4                3                  1                   1            2022
#
#    timestamp_week  timestamp_day_of_week  timestamp_day_of_month  \
# 0              13                      3                      31
# 1              13                      3                      31
# 2              13                      3                      31
# 3              13                      3                      31
# 4              13                      3                      31
#
#    timestamp_day_of_year  timestamp_weekend  timestamp_month_start  \
# 0                     90                  0                      0
# 1                     90                  0                      0
# 2                     90                  0                      0
# 3                     90                  0                      0
# 4                     90                  0                      0
#
#    timestamp_month_end  timestamp_quarter_start  timestamp_quarter_end  \
# 0                    1                        0                      1
# 1                    1                        0                      1
# 2                    1                        0                      1
# 3                    1                        0                      1
# 4                    1                        0                      1
#
#    timestamp_year_start  timestamp_year_end  timestamp_leap_year  \
# 0                     0                   0                    0
# 1                     0                   0                    0
# 2                     0                   0                    0
# 3                     0                   0                    0
# 4                     0                   0                    0
#
#    timestamp_days_in_month  timestamp_hour  timestamp_minute  timestamp_second
# 0                       31              15                 0                 0
# 1                       31              16                 0                 0
# 2                       31              17                 0                 0
# 3                       31              18                 0                 0
# 4                       31              19                 0                 0

# %%
temporal.head().T
# Out:
#                             0     1     2     3     4
# timestamp_month             3     3     3     3     3
# timestamp_quarter           1     1     1     1     1
# timestamp_semester          1     1     1     1     1
# timestamp_year           2022  2022  2022  2022  2022
# timestamp_week             13    13    13    13    13
# timestamp_day_of_week       3     3     3     3     3
# timestamp_day_of_month     31    31    31    31    31
# timestamp_day_of_year      90    90    90    90    90
# timestamp_weekend           0     0     0     0     0
# timestamp_month_start       0     0     0     0     0
# timestamp_month_end         1     1     1     1     1
# timestamp_quarter_start     0     0     0     0     0
# timestamp_quarter_end       1     1     1     1     1
# timestamp_year_start        0     0     0     0     0
# timestamp_year_end          0     0     0     0     0
# timestamp_leap_year         0     0     0     0     0
# timestamp_days_in_month    31    31    31    31    31
# timestamp_hour             15    16    17    18    19
# timestamp_minute            0     0     0     0     0
# timestamp_second            0     0     0     0     0

# %%
add_temporal_features(df)

# %%
df.head().T
# Out:
#                                            0                    1  \
# passenger_demand                           4                    3
# taxi_demand                                4                    3
# timestamp                2022-03-31 15:00:00  2022-03-31 16:00:00
# timestamp_month                            3                    3
# timestamp_quarter                          1                    1
# timestamp_semester                         1                    1
# timestamp_year                          2022                 2022
# timestamp_week                            13                   13
# timestamp_day_of_week                      3                    3
# timestamp_day_of_month                    31                   31
# timestamp_day_of_year                     90                   90
# timestamp_weekend                          0                    0
# timestamp_month_start                      0                    0
# timestamp_month_end                        1                    1
# timestamp_quarter_start                    0                    0
# timestamp_quarter_end                      1                    1
# timestamp_year_start                       0                    0
# timestamp_year_end                         0                    0
# timestamp_leap_year                        0                    0
# timestamp_days_in_month                   31                   31
# timestamp_hour                            15                   16
# timestamp_minute                           0                    0
# timestamp_second                           0                    0
#
#                                            2                    3  \
# passenger_demand                           0                    0
# taxi_demand                                0                    0
# timestamp                2022-03-31 17:00:00  2022-03-31 18:00:00
# timestamp_month                            3                    3
# timestamp_quarter                          1                    1
# timestamp_semester                         1                    1
# timestamp_year                          2022                 2022
# timestamp_week                            13                   13
# timestamp_day_of_week                      3                    3
# timestamp_day_of_month                    31                   31
# timestamp_day_of_year                     90                   90
# timestamp_weekend                          0                    0
# timestamp_month_start                      0                    0
# timestamp_month_end                        1                    1
# timestamp_quarter_start                    0                    0
# timestamp_quarter_end                      1                    1
# timestamp_year_start                       0                    0
# timestamp_year_end                         0                    0
# timestamp_leap_year                        0                    0
# timestamp_days_in_month                   31                   31
# timestamp_hour                            17                   18
# timestamp_minute                           0                    0
# timestamp_second                           0                    0
#
#                                            4
# passenger_demand                           0
# taxi_demand                                0
# timestamp                2022-03-31 19:00:00
# timestamp_month                            3
# timestamp_quarter                          1
# timestamp_semester                         1
# timestamp_year                          2022
# timestamp_week                            13
# timestamp_day_of_week                      3
# timestamp_day_of_month                    31
# timestamp_day_of_year                     90
# timestamp_weekend                          0
# timestamp_month_start                      0
# timestamp_month_end                        1
# timestamp_quarter_start                    0
# timestamp_quarter_end                      1
# timestamp_year_start                       0
# timestamp_year_end                         0
# timestamp_leap_year                        0
# timestamp_days_in_month                   31
# timestamp_hour                            19
# timestamp_minute                           0
# timestamp_second                           0

# %% [markdown]
# # LagFeatures

# %% [markdown]
# <b>Lag:</b> In various fields, "lag" often refers to a delay or a period of time between two events or actions. For instance, in economics or finance, it might represent the delay between a policy change and its effects on the economy. In statistics, a lag is a shift in time for a variable in a time series analysis. It's used to observe the relationship between past and present values of a variable.

# %%
# LagFeatures?

# %%
lagfeatures = LagFeatures(variables=None, periods=[1, 2, 4, 8, 16, 24], freq=None, sort_index=True,
                          missing_values='raise', drop_original=False)
lagfeatures.fit(df[['timestamp', 'passenger_demand', 'taxi_demand']])
features = lagfeatures.transform(df[['timestamp', 'passenger_demand', 'taxi_demand']])
features
# Out:
#                timestamp  passenger_demand  taxi_demand  \
# 0    2022-03-31 15:00:00                 4            4
# 1    2022-03-31 16:00:00                 3            3
# 2    2022-03-31 17:00:00                 0            0
# 3    2022-03-31 18:00:00                 0            0
# 4    2022-03-31 19:00:00                 0            0
# ...                  ...               ...          ...
# 8732 2022-05-31 11:00:00              8489         6242
# 8733 2022-05-31 12:00:00              8714         6444
# 8734 2022-05-31 13:00:00              9389         6915
# 8735 2022-05-31 14:00:00              9997         7296
# 8736 2022-05-31 15:00:00             10589         7618
#
#       passenger_demand_lag_1  taxi_demand_lag_1  passenger_demand_lag_2  \
# 0                        NaN                NaN                     NaN
# 1                        4.0                4.0                     NaN
# 2                        3.0                3.0                     4.0
# 3                        0.0                0.0                     3.0
# 4                        0.0                0.0                     0.0
# ...                      ...                ...                     ...
# 8732                  7741.0             5744.0                  7626.0
# 8733                  8489.0             6242.0                  7741.0
# 8734                  8714.0             6444.0                  8489.0
# 8735                  9389.0             6915.0                  8714.0
# 8736                  9997.0             7296.0                  9389.0
#
#       taxi_demand_lag_2  passenger_demand_lag_4  taxi_demand_lag_4  \
# 0                   NaN                     NaN                NaN
# 1                   NaN                     NaN                NaN
# 2                   4.0                     NaN                NaN
# 3                   3.0                     NaN                NaN
# 4                   0.0                     4.0                4.0
# ...                 ...                     ...                ...
# 8732             5787.0                  5599.0             4318.0
# 8733             5744.0                  7174.0             5559.0
# 8734             6242.0                  7626.0             5787.0
# 8735             6444.0                  7741.0             5744.0
# 8736             6915.0                  8489.0             6242.0
#
#       passenger_demand_lag_8  taxi_demand_lag_8  passenger_demand_lag_16  \
# 0                        NaN                NaN                      NaN
# 1                        NaN                NaN                      NaN
# 2                        NaN                NaN                      NaN
# 3                        NaN                NaN                      NaN
# 4                        NaN                NaN                      NaN
# ...                      ...                ...                      ...
# 8732                   342.0              231.0                   7850.0
# 8733                   454.0              321.0                   6974.0
# 8734                  1104.0              808.0                   6762.0
# 8735                  2763.0             2182.0                   5796.0
# 8736                  5599.0             4318.0                   4261.0
#
#       taxi_demand_lag_16  passenger_demand_lag_24  taxi_demand_lag_24
# 0                    NaN                      NaN                 NaN
# 1                    NaN                      NaN                 NaN
# 2                    NaN                      NaN                 NaN
# 3                    NaN                      NaN                 NaN
# 4                    NaN                      NaN                 NaN
# ...                  ...                      ...                 ...
# 8732              5418.0                   6166.0              4208.0
# 8733              4783.0                   7738.0              5135.0
# 8734              4628.0                   8225.0              5475.0
# 8735              3980.0                   8518.0              5735.0
# 8736              2958.0                   9018.0              5965.0
#
# [8737 rows x 15 columns]

# %%
def add_lag_features(df:pd.DataFrame) -> pd.DataFrame:
    lagfeatures = LagFeatures(variables=None, periods=[1, 2, 4, 8, 16, 24], freq=None, sort_index=True,
                              missing_values='raise', drop_original=False)
    lagfeatures.fit(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    features = lagfeatures.transform(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    for col in list(features.columns)[3:]:
        df[col] = features[col].values

# %%
add_lag_features(df)

# %%
df.head().T
# Out:
#                                            0                    1  \
# passenger_demand                           4                    3
# taxi_demand                                4                    3
# timestamp                2022-03-31 15:00:00  2022-03-31 16:00:00
# timestamp_month                            3                    3
# timestamp_quarter                          1                    1
# timestamp_semester                         1                    1
# timestamp_year                          2022                 2022
# timestamp_week                            13                   13
# timestamp_day_of_week                      3                    3
# timestamp_day_of_month                    31                   31
# timestamp_day_of_year                     90                   90
# timestamp_weekend                          0                    0
# timestamp_month_start                      0                    0
# timestamp_month_end                        1                    1
# timestamp_quarter_start                    0                    0
# timestamp_quarter_end                      1                    1
# timestamp_year_start                       0                    0
# timestamp_year_end                         0                    0
# timestamp_leap_year                        0                    0
# timestamp_days_in_month                   31                   31
# timestamp_hour                            15                   16
# timestamp_minute                           0                    0
# timestamp_second                           0                    0
# passenger_demand_lag_1                   NaN                  4.0
# taxi_demand_lag_1                        NaN                  4.0
# passenger_demand_lag_2                   NaN                  NaN
# taxi_demand_lag_2                        NaN                  NaN
# passenger_demand_lag_4                   NaN                  NaN
# taxi_demand_lag_4                        NaN                  NaN
# passenger_demand_lag_8                   NaN                  NaN
# taxi_demand_lag_8                        NaN                  NaN
# passenger_demand_lag_16                  NaN                  NaN
# taxi_demand_lag_16                       NaN                  NaN
# passenger_demand_lag_24                  NaN                  NaN
# taxi_demand_lag_24                       NaN                  NaN
#
#                                            2                    3  \
# passenger_demand                           0                    0
# taxi_demand                                0                    0
# timestamp                2022-03-31 17:00:00  2022-03-31 18:00:00
# timestamp_month                            3                    3
# timestamp_quarter                          1                    1
# timestamp_semester                         1                    1
# timestamp_year                          2022                 2022
# timestamp_week                            13                   13
# timestamp_day_of_week                      3                    3
# timestamp_day_of_month                    31                   31
# timestamp_day_of_year                     90                   90
# timestamp_weekend                          0                    0
# timestamp_month_start                      0                    0
# timestamp_month_end                        1                    1
# timestamp_quarter_start                    0                    0
# timestamp_quarter_end                      1                    1
# timestamp_year_start                       0                    0
# timestamp_year_end                         0                    0
# timestamp_leap_year                        0                    0
# timestamp_days_in_month                   31                   31
# timestamp_hour                            17                   18
# timestamp_minute                           0                    0
# timestamp_second                           0                    0
# passenger_demand_lag_1                   3.0                  0.0
# taxi_demand_lag_1                        3.0                  0.0
# passenger_demand_lag_2                   4.0                  3.0
# taxi_demand_lag_2                        4.0                  3.0
# passenger_demand_lag_4                   NaN                  NaN
# taxi_demand_lag_4                        NaN                  NaN
# passenger_demand_lag_8                   NaN                  NaN
# taxi_demand_lag_8                        NaN                  NaN
# passenger_demand_lag_16                  NaN                  NaN
# taxi_demand_lag_16                       NaN                  NaN
# passenger_demand_lag_24                  NaN                  NaN
# taxi_demand_lag_24                       NaN                  NaN
#
#                                            4
# passenger_demand                           0
# taxi_demand                                0
# timestamp                2022-03-31 19:00:00
# timestamp_month                            3
# timestamp_quarter                          1
# timestamp_semester                         1
# timestamp_year                          2022
# timestamp_week                            13
# timestamp_day_of_week                      3
# timestamp_day_of_month                    31
# timestamp_day_of_year                     90
# timestamp_weekend                          0
# timestamp_month_start                      0
# timestamp_month_end                        1
# timestamp_quarter_start                    0
# timestamp_quarter_end                      1
# timestamp_year_start                       0
# timestamp_year_end                         0
# timestamp_leap_year                        0
# timestamp_days_in_month                   31
# timestamp_hour                            19
# timestamp_minute                           0
# timestamp_second                           0
# passenger_demand_lag_1                   0.0
# taxi_demand_lag_1                        0.0
# passenger_demand_lag_2                   0.0
# taxi_demand_lag_2                        0.0
# passenger_demand_lag_4                   4.0
# taxi_demand_lag_4                        4.0
# passenger_demand_lag_8                   NaN
# taxi_demand_lag_8                        NaN
# passenger_demand_lag_16                  NaN
# taxi_demand_lag_16                       NaN
# passenger_demand_lag_24                  NaN
# taxi_demand_lag_24                       NaN

# %% [markdown]
# # WindowFeatures

# %% [markdown]
# <b>Windowing in Data Analysis:</b> In data analysis or signal processing, a window function is a mathematical function that modifies a time series or sequence of data to emphasize or de-emphasize certain points. It's often used in techniques like Fourier analysis, signal processing, and data smoothing. The function "windows" or narrows the focus to a specific section of the data, reducing the impact of values outside that section.
#
# Both concepts are crucial in various domains, helping to understand patterns, relationships, and the behavior of data over time.
#
# The mean value of the previous 3 months of data is a window feature. The
# maximum value of the previous three rows of data is another window feature.

# %%
# WindowFeatures?

# %%
def add_window_features(df:pd.DataFrame) -> pd.DataFrame:
    window = WindowFeatures(
        variables=None, window=7, min_periods=1, 
        functions=['mean', 'std', 'median'], periods=1, freq=None, sort_index=True, 
        missing_values='raise', drop_original=False
    )
    window.fit(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    features = window.transform(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    for col in list(features.columns)[3:]:
        df[col] = features[col].values

# %%
window = WindowFeatures(
    variables=None, window=7, min_periods=1, 
    functions=['mean', 'std', 'median'], periods=1, freq=None, sort_index=True, 
    missing_values='raise', drop_original=False
)

# %%
window.fit_transform(df[['timestamp', 'passenger_demand', 'taxi_demand']]).head(10).T
# Out:
#                                                     0                    1  \
# timestamp                         2022-03-31 15:00:00  2022-03-31 16:00:00
# passenger_demand                                    4                    3
# taxi_demand                                         4                    3
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
#
#                                                     2                    3  \
# timestamp                         2022-03-31 17:00:00  2022-03-31 18:00:00
# passenger_demand                                    0                    0
# taxi_demand                                         0                    0
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
#
#                                                     4                    5  \
# timestamp                         2022-03-31 19:00:00  2022-03-31 20:00:00
# passenger_demand                                    0                    0
# taxi_demand                                         0                    0
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
#
#                                                     6                    7  \
# timestamp                         2022-03-31 21:00:00  2022-03-31 22:00:00
# passenger_demand                                    0                    2
# taxi_demand                                         0                    1
# passenger_demand_window_7_mean                    NaN                  1.0
# passenger_demand_window_7_std                     NaN             1.732051
# passenger_demand_window_7_median                  NaN                  0.0
# taxi_demand_window_7_mean                         NaN                  1.0
# taxi_demand_window_7_std                          NaN             1.732051
# taxi_demand_window_7_median                       NaN                  0.0
#
#                                                     8                    9
# timestamp                         2022-03-31 23:00:00  2022-04-01 00:00:00
# passenger_demand                                  121                 5046
# taxi_demand                                        65                 3509
# passenger_demand_window_7_mean               0.714286            17.571429
# passenger_demand_window_7_std                1.253566            45.613803
# passenger_demand_window_7_median                  0.0                  0.0
# taxi_demand_window_7_mean                    0.571429             9.428571
# taxi_demand_window_7_std                     1.133893             24.50753
# taxi_demand_window_7_median                       0.0                  0.0

# %%
add_window_features(df)

# %%
df.head().T
# Out:
#                                                     0                    1  \
# passenger_demand                                    4                    3
# taxi_demand                                         4                    3
# timestamp                         2022-03-31 15:00:00  2022-03-31 16:00:00
# timestamp_month                                     3                    3
# timestamp_quarter                                   1                    1
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               3                    3
# timestamp_day_of_month                             31                   31
# timestamp_day_of_year                              90                   90
# timestamp_weekend                                   0                    0
# timestamp_month_start                               0                    0
# timestamp_month_end                                 1                    1
# timestamp_quarter_start                             0                    0
# timestamp_quarter_end                               1                    1
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            31                   31
# timestamp_hour                                     15                   16
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                            NaN                  4.0
# taxi_demand_lag_1                                 NaN                  4.0
# passenger_demand_lag_2                            NaN                  NaN
# taxi_demand_lag_2                                 NaN                  NaN
# passenger_demand_lag_4                            NaN                  NaN
# taxi_demand_lag_4                                 NaN                  NaN
# passenger_demand_lag_8                            NaN                  NaN
# taxi_demand_lag_8                                 NaN                  NaN
# passenger_demand_lag_16                           NaN                  NaN
# taxi_demand_lag_16                                NaN                  NaN
# passenger_demand_lag_24                           NaN                  NaN
# taxi_demand_lag_24                                NaN                  NaN
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
#
#                                                     2                    3  \
# passenger_demand                                    0                    0
# taxi_demand                                         0                    0
# timestamp                         2022-03-31 17:00:00  2022-03-31 18:00:00
# timestamp_month                                     3                    3
# timestamp_quarter                                   1                    1
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               3                    3
# timestamp_day_of_month                             31                   31
# timestamp_day_of_year                              90                   90
# timestamp_weekend                                   0                    0
# timestamp_month_start                               0                    0
# timestamp_month_end                                 1                    1
# timestamp_quarter_start                             0                    0
# timestamp_quarter_end                               1                    1
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            31                   31
# timestamp_hour                                     17                   18
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                            3.0                  0.0
# taxi_demand_lag_1                                 3.0                  0.0
# passenger_demand_lag_2                            4.0                  3.0
# taxi_demand_lag_2                                 4.0                  3.0
# passenger_demand_lag_4                            NaN                  NaN
# taxi_demand_lag_4                                 NaN                  NaN
# passenger_demand_lag_8                            NaN                  NaN
# taxi_demand_lag_8                                 NaN                  NaN
# passenger_demand_lag_16                           NaN                  NaN
# taxi_demand_lag_16                                NaN                  NaN
# passenger_demand_lag_24                           NaN                  NaN
# taxi_demand_lag_24                                NaN                  NaN
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
#
#                                                     4
# passenger_demand                                    0
# taxi_demand                                         0
# timestamp                         2022-03-31 19:00:00
# timestamp_month                                     3
# timestamp_quarter                                   1
# timestamp_semester                                  1
# timestamp_year                                   2022
# timestamp_week                                     13
# timestamp_day_of_week                               3
# timestamp_day_of_month                             31
# timestamp_day_of_year                              90
# timestamp_weekend                                   0
# timestamp_month_start                               0
# timestamp_month_end                                 1
# timestamp_quarter_start                             0
# timestamp_quarter_end                               1
# timestamp_year_start                                0
# timestamp_year_end                                  0
# timestamp_leap_year                                 0
# timestamp_days_in_month                            31
# timestamp_hour                                     19
# timestamp_minute                                    0
# timestamp_second                                    0
# passenger_demand_lag_1                            0.0
# taxi_demand_lag_1                                 0.0
# passenger_demand_lag_2                            0.0
# taxi_demand_lag_2                                 0.0
# passenger_demand_lag_4                            4.0
# taxi_demand_lag_4                                 4.0
# passenger_demand_lag_8                            NaN
# taxi_demand_lag_8                                 NaN
# passenger_demand_lag_16                           NaN
# taxi_demand_lag_16                                NaN
# passenger_demand_lag_24                           NaN
# taxi_demand_lag_24                                NaN
# passenger_demand_window_7_mean                    NaN
# passenger_demand_window_7_std                     NaN
# passenger_demand_window_7_median                  NaN
# taxi_demand_window_7_mean                         NaN
# taxi_demand_window_7_std                          NaN
# taxi_demand_window_7_median                       NaN

# %% [markdown]
# # ExpandingWindowFeatures

# %%
# ExpandingWindowFeatures?

# %%
def add_exp_window_features(df:pd.DataFrame) -> pd.DataFrame:
    expwindow = ExpandingWindowFeatures(
        variables=None, min_periods=None, functions='std', 
        periods=1, freq=None, sort_index=True, 
        missing_values='raise', drop_original=False
    )
    expwindow.fit(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    features = expwindow.transform(df[['timestamp', 'passenger_demand', 'taxi_demand']])
    for col in list(features.columns)[3:]:
        df[col] = features[col].values

# %%
expwindow = ExpandingWindowFeatures(
    variables=None, min_periods=None, functions='std', 
    periods=1, freq=None, sort_index=True, 
    missing_values='raise', drop_original=False
)

# %%
expwindow.fit_transform(df[['timestamp', 'passenger_demand', 'taxi_demand']]).head(10).T
# Out:
#                                                   0                    1  \
# timestamp                       2022-03-31 15:00:00  2022-03-31 16:00:00
# passenger_demand                                  4                    3
# taxi_demand                                       4                    3
# passenger_demand_expanding_std                  NaN                  NaN
# taxi_demand_expanding_std                       NaN                  NaN
#
#                                                   2                    3  \
# timestamp                       2022-03-31 17:00:00  2022-03-31 18:00:00
# passenger_demand                                  0                    0
# taxi_demand                                       0                    0
# passenger_demand_expanding_std             0.707107             2.081666
# taxi_demand_expanding_std                  0.707107             2.081666
#
#                                                   4                    5  \
# timestamp                       2022-03-31 19:00:00  2022-03-31 20:00:00
# passenger_demand                                  0                    0
# taxi_demand                                       0                    0
# passenger_demand_expanding_std             2.061553             1.949359
# taxi_demand_expanding_std                  2.061553             1.949359
#
#                                                   6                    7  \
# timestamp                       2022-03-31 21:00:00  2022-03-31 22:00:00
# passenger_demand                                  0                    2
# taxi_demand                                       0                    1
# passenger_demand_expanding_std             1.834848             1.732051
# taxi_demand_expanding_std                  1.834848             1.732051
#
#                                                   8                    9
# timestamp                       2022-03-31 23:00:00  2022-04-01 00:00:00
# passenger_demand                                121                 5046
# taxi_demand                                      65                 3509
# passenger_demand_expanding_std             1.642081            39.987845
# taxi_demand_expanding_std                  1.603567            21.386003

# %%
add_exp_window_features(df)

# %%
df.head().T
# Out:
#                                                     0                    1  \
# passenger_demand                                    4                    3
# taxi_demand                                         4                    3
# timestamp                         2022-03-31 15:00:00  2022-03-31 16:00:00
# timestamp_month                                     3                    3
# timestamp_quarter                                   1                    1
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               3                    3
# timestamp_day_of_month                             31                   31
# timestamp_day_of_year                              90                   90
# timestamp_weekend                                   0                    0
# timestamp_month_start                               0                    0
# timestamp_month_end                                 1                    1
# timestamp_quarter_start                             0                    0
# timestamp_quarter_end                               1                    1
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            31                   31
# timestamp_hour                                     15                   16
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                            NaN                  4.0
# taxi_demand_lag_1                                 NaN                  4.0
# passenger_demand_lag_2                            NaN                  NaN
# taxi_demand_lag_2                                 NaN                  NaN
# passenger_demand_lag_4                            NaN                  NaN
# taxi_demand_lag_4                                 NaN                  NaN
# passenger_demand_lag_8                            NaN                  NaN
# taxi_demand_lag_8                                 NaN                  NaN
# passenger_demand_lag_16                           NaN                  NaN
# taxi_demand_lag_16                                NaN                  NaN
# passenger_demand_lag_24                           NaN                  NaN
# taxi_demand_lag_24                                NaN                  NaN
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
# passenger_demand_expanding_std                    NaN                  NaN
# taxi_demand_expanding_std                         NaN                  NaN
#
#                                                     2                    3  \
# passenger_demand                                    0                    0
# taxi_demand                                         0                    0
# timestamp                         2022-03-31 17:00:00  2022-03-31 18:00:00
# timestamp_month                                     3                    3
# timestamp_quarter                                   1                    1
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               3                    3
# timestamp_day_of_month                             31                   31
# timestamp_day_of_year                              90                   90
# timestamp_weekend                                   0                    0
# timestamp_month_start                               0                    0
# timestamp_month_end                                 1                    1
# timestamp_quarter_start                             0                    0
# timestamp_quarter_end                               1                    1
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            31                   31
# timestamp_hour                                     17                   18
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                            3.0                  0.0
# taxi_demand_lag_1                                 3.0                  0.0
# passenger_demand_lag_2                            4.0                  3.0
# taxi_demand_lag_2                                 4.0                  3.0
# passenger_demand_lag_4                            NaN                  NaN
# taxi_demand_lag_4                                 NaN                  NaN
# passenger_demand_lag_8                            NaN                  NaN
# taxi_demand_lag_8                                 NaN                  NaN
# passenger_demand_lag_16                           NaN                  NaN
# taxi_demand_lag_16                                NaN                  NaN
# passenger_demand_lag_24                           NaN                  NaN
# taxi_demand_lag_24                                NaN                  NaN
# passenger_demand_window_7_mean                    NaN                  NaN
# passenger_demand_window_7_std                     NaN                  NaN
# passenger_demand_window_7_median                  NaN                  NaN
# taxi_demand_window_7_mean                         NaN                  NaN
# taxi_demand_window_7_std                          NaN                  NaN
# taxi_demand_window_7_median                       NaN                  NaN
# passenger_demand_expanding_std               0.707107             2.081666
# taxi_demand_expanding_std                    0.707107             2.081666
#
#                                                     4
# passenger_demand                                    0
# taxi_demand                                         0
# timestamp                         2022-03-31 19:00:00
# timestamp_month                                     3
# timestamp_quarter                                   1
# timestamp_semester                                  1
# timestamp_year                                   2022
# timestamp_week                                     13
# timestamp_day_of_week                               3
# timestamp_day_of_month                             31
# timestamp_day_of_year                              90
# timestamp_weekend                                   0
# timestamp_month_start                               0
# timestamp_month_end                                 1
# timestamp_quarter_start                             0
# timestamp_quarter_end                               1
# timestamp_year_start                                0
# timestamp_year_end                                  0
# timestamp_leap_year                                 0
# timestamp_days_in_month                            31
# timestamp_hour                                     19
# timestamp_minute                                    0
# timestamp_second                                    0
# passenger_demand_lag_1                            0.0
# taxi_demand_lag_1                                 0.0
# passenger_demand_lag_2                            0.0
# taxi_demand_lag_2                                 0.0
# passenger_demand_lag_4                            4.0
# taxi_demand_lag_4                                 4.0
# passenger_demand_lag_8                            NaN
# taxi_demand_lag_8                                 NaN
# passenger_demand_lag_16                           NaN
# taxi_demand_lag_16                                NaN
# passenger_demand_lag_24                           NaN
# taxi_demand_lag_24                                NaN
# passenger_demand_window_7_mean                    NaN
# passenger_demand_window_7_std                     NaN
# passenger_demand_window_7_median                  NaN
# taxi_demand_window_7_mean                         NaN
# taxi_demand_window_7_std                          NaN
# taxi_demand_window_7_median                       NaN
# passenger_demand_expanding_std               2.061553
# taxi_demand_expanding_std                    2.061553

# %%
df.dropna(inplace=True)

# %%
# Lets Check again NaN values

# %%
df.head(7).T
# Out:
#                                                    24                   25  \
# passenger_demand                                12127                11245
# taxi_demand                                      8487                 7888
# timestamp                         2022-04-01 15:00:00  2022-04-01 16:00:00
# timestamp_month                                     4                    4
# timestamp_quarter                                   2                    2
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               4                    4
# timestamp_day_of_month                              1                    1
# timestamp_day_of_year                              91                   91
# timestamp_weekend                                   0                    0
# timestamp_month_start                               1                    1
# timestamp_month_end                                 0                    0
# timestamp_quarter_start                             1                    1
# timestamp_quarter_end                               0                    0
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            30                   30
# timestamp_hour                                     15                   16
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                        10909.0              12127.0
# taxi_demand_lag_1                              7792.0               8487.0
# passenger_demand_lag_2                         9394.0              10909.0
# taxi_demand_lag_2                              6896.0               7792.0
# passenger_demand_lag_4                         8683.0               9145.0
# taxi_demand_lag_4                              6294.0               6672.0
# passenger_demand_lag_8                         5653.0               7085.0
# taxi_demand_lag_8                              4262.0               5271.0
# passenger_demand_lag_16                         121.0               5046.0
# taxi_demand_lag_16                               65.0               3509.0
# passenger_demand_lag_24                           4.0                  3.0
# taxi_demand_lag_24                                4.0                  3.0
# passenger_demand_window_7_mean                 8667.0          9387.285714
# passenger_demand_window_7_std             1319.548534           1647.44476
# passenger_demand_window_7_median               8683.0               9145.0
# taxi_demand_window_7_mean                      6337.0          6796.428571
# taxi_demand_window_7_std                   878.098704          1051.583387
# taxi_demand_window_7_median                    6294.0               6672.0
# passenger_demand_expanding_std            3823.294951          4127.546522
# taxi_demand_expanding_std                  2793.79498          2986.330622
#
#                                                    26                   27  \
# passenger_demand                                13665                14770
# taxi_demand                                      9788                10527
# timestamp                         2022-04-01 17:00:00  2022-04-01 18:00:00
# timestamp_month                                     4                    4
# timestamp_quarter                                   2                    2
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               4                    4
# timestamp_day_of_month                              1                    1
# timestamp_day_of_year                              91                   91
# timestamp_weekend                                   0                    0
# timestamp_month_start                               1                    1
# timestamp_month_end                                 0                    0
# timestamp_quarter_start                             1                    1
# timestamp_quarter_end                               0                    0
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            30                   30
# timestamp_hour                                     17                   18
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                        11245.0              13665.0
# taxi_demand_lag_1                              7888.0               9788.0
# passenger_demand_lag_2                        12127.0              11245.0
# taxi_demand_lag_2                              8487.0               7888.0
# passenger_demand_lag_4                         9394.0              10909.0
# taxi_demand_lag_4                              6896.0               7792.0
# passenger_demand_lag_8                         7284.0               8169.0
# taxi_demand_lag_8                              5419.0               6015.0
# passenger_demand_lag_16                        3159.0               1850.0
# taxi_demand_lag_16                             2182.0               1284.0
# passenger_demand_lag_24                           0.0                  0.0
# taxi_demand_lag_24                                0.0                  0.0
# passenger_demand_window_7_mean            9953.142857         10738.285714
# passenger_demand_window_7_std             1475.939072          1795.826153
# passenger_demand_window_7_median               9394.0              10909.0
# taxi_demand_window_7_mean                 7149.142857          7688.142857
# taxi_demand_window_7_std                   918.180525          1204.295981
# taxi_demand_window_7_median                    6896.0               7792.0
# passenger_demand_expanding_std            4301.369187          4604.987587
# taxi_demand_expanding_std                  3095.86728          3310.305959
#
#                                                    28                   29  \
# passenger_demand                                13868                11739
# taxi_demand                                      9697                 7972
# timestamp                         2022-04-01 19:00:00  2022-04-01 20:00:00
# timestamp_month                                     4                    4
# timestamp_quarter                                   2                    2
# timestamp_semester                                  1                    1
# timestamp_year                                   2022                 2022
# timestamp_week                                     13                   13
# timestamp_day_of_week                               4                    4
# timestamp_day_of_month                              1                    1
# timestamp_day_of_year                              91                   91
# timestamp_weekend                                   0                    0
# timestamp_month_start                               1                    1
# timestamp_month_end                                 0                    0
# timestamp_quarter_start                             1                    1
# timestamp_quarter_end                               0                    0
# timestamp_year_start                                0                    0
# timestamp_year_end                                  0                    0
# timestamp_leap_year                                 0                    0
# timestamp_days_in_month                            30                   30
# timestamp_hour                                     19                   20
# timestamp_minute                                    0                    0
# timestamp_second                                    0                    0
# passenger_demand_lag_1                        14770.0              13868.0
# taxi_demand_lag_1                             10527.0               9697.0
# passenger_demand_lag_2                        13665.0              14770.0
# taxi_demand_lag_2                              9788.0              10527.0
# passenger_demand_lag_4                        12127.0              11245.0
# taxi_demand_lag_4                              8487.0               7888.0
# passenger_demand_lag_8                         8683.0               9145.0
# taxi_demand_lag_8                              6294.0               6672.0
# passenger_demand_lag_16                         894.0                855.0
# taxi_demand_lag_16                              622.0                571.0
# passenger_demand_lag_24                           0.0                  0.0
# taxi_demand_lag_24                                0.0                  0.0
# passenger_demand_window_7_mean           11607.857143         12282.571429
# passenger_demand_window_7_std             2085.161419          1912.384799
# passenger_demand_window_7_median              11245.0              12127.0
# taxi_demand_window_7_mean                 8292.857143               8725.0
# taxi_demand_window_7_std                  1429.317603          1309.891853
# taxi_demand_window_7_median                    7888.0               8487.0
# passenger_demand_expanding_std            4924.257225          5121.121104
# taxi_demand_expanding_std                 3532.477627          3657.920979
#
#                                                    30
# passenger_demand                                11102
# taxi_demand                                      7380
# timestamp                         2022-04-01 21:00:00
# timestamp_month                                     4
# timestamp_quarter                                   2
# timestamp_semester                                  1
# timestamp_year                                   2022
# timestamp_week                                     13
# timestamp_day_of_week                               4
# timestamp_day_of_month                              1
# timestamp_day_of_year                              91
# timestamp_weekend                                   0
# timestamp_month_start                               1
# timestamp_month_end                                 0
# timestamp_quarter_start                             1
# timestamp_quarter_end                               0
# timestamp_year_start                                0
# timestamp_year_end                                  0
# timestamp_leap_year                                 0
# timestamp_days_in_month                            30
# timestamp_hour                                     21
# timestamp_minute                                    0
# timestamp_second                                    0
# passenger_demand_lag_1                        11739.0
# taxi_demand_lag_1                              7972.0
# passenger_demand_lag_2                        13868.0
# taxi_demand_lag_2                              9697.0
# passenger_demand_lag_4                        13665.0
# taxi_demand_lag_4                              9788.0
# passenger_demand_lag_8                         9394.0
# taxi_demand_lag_8                              6896.0
# passenger_demand_lag_16                        1145.0
# taxi_demand_lag_16                              813.0
# passenger_demand_lag_24                           0.0
# taxi_demand_lag_24                                0.0
# passenger_demand_window_7_mean           12617.571429
# passenger_demand_window_7_std             1478.137551
# passenger_demand_window_7_median              12127.0
# taxi_demand_window_7_mean                 8878.714286
# taxi_demand_window_7_std                  1106.892906
# taxi_demand_window_7_median                    8487.0
# passenger_demand_expanding_std            5175.970925
# taxi_demand_expanding_std                 3679.466546

# %% [markdown]
# # Lets Save The FeaturesEngineering Data

# %%
df.to_parquet(r"C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/data/2022/V3_FeatureEngineering_Data.parquet", index=False)
