# %% [markdown]
# # Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dask.dataframe as dd

from dask.distributed import Client, LocalCluster

# %matplotlib inline

# %% [markdown]
# # Loading Data

# %%
ddf = dd.read_parquet(r"C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/january_2023-01.parquet", npartiations = 1)
ddf.compute().head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
ddf.compute().head().T
# Out:
#                                          0                    1  \
# VendorID                                 2                    2
# tpep_pickup_datetime   2023-01-01 00:32:10  2023-01-01 00:55:08
# tpep_dropoff_datetime  2023-01-01 00:40:36  2023-01-01 01:01:27
# passenger_count                        1.0                  1.0
# trip_distance                         0.97                  1.1
# RatecodeID                             1.0                  1.0
# store_and_fwd_flag                       N                    N
# PULocationID                           161                   43
# DOLocationID                           141                  237
# payment_type                             2                    1
# fare_amount                            9.3                  7.9
# extra                                  1.0                  1.0
# mta_tax                                0.5                  0.5
# tip_amount                             0.0                  4.0
# ...

# %%
# let me set "tpep_pickup_datetime" as index

# %%
ddf = ddf.set_index(ddf.tpep_pickup_datetime, sorted = True)

# %%
ddf.compute().head().T
# Out:
# tpep_pickup_datetime   2023-01-01 00:32:10  2023-01-01 00:55:08  \
# VendorID                                 2                    2
# tpep_pickup_datetime   2023-01-01 00:32:10  2023-01-01 00:55:08
# tpep_dropoff_datetime  2023-01-01 00:40:36  2023-01-01 01:01:27
# passenger_count                        1.0                  1.0
# trip_distance                         0.97                  1.1
# RatecodeID                             1.0                  1.0
# store_and_fwd_flag                       N                    N
# PULocationID                           161                   43
# DOLocationID                           141                  237
# payment_type                             2                    1
# fare_amount                            9.3                  7.9
# extra                                  1.0                  1.0
# mta_tax                                0.5                  0.5
# tip_amount                             0.0                  4.0
# ...

# %%
ddf.compute().tail()
# Out:
#                       VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# tpep_pickup_datetime
# 2023-01-31 23:58:34          2  2023-01-31 23:58:34   2023-02-01 00:12:33
# 2023-01-31 23:31:09          2  2023-01-31 23:31:09   2023-01-31 23:50:36
# 2023-01-31 23:01:05          2  2023-01-31 23:01:05   2023-01-31 23:25:36
# 2023-01-31 23:40:00          2  2023-01-31 23:40:00   2023-01-31 23:53:00
# 2023-01-31 23:07:32          2  2023-01-31 23:07:32   2023-01-31 23:21:56
#
#                       passenger_count  trip_distance  RatecodeID  \
# tpep_pickup_datetime
# 2023-01-31 23:58:34               NaN           3.05         NaN
# 2023-01-31 23:31:09               NaN           5.80         NaN
# 2023-01-31 23:01:05               NaN           4.67         NaN
# 2023-01-31 23:40:00               NaN           3.15         NaN
# 2023-01-31 23:07:32               NaN           2.85         NaN
#
#                      store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
ddf.compute().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3066766 entries, 2023-01-01 00:32:10 to 2023-01-31 23:07:32
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     string
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# ...

# %%
# There is datetime64[us](2), float64(12), int64(4), string(1)
# 2463931 rows, 18 columns

# %%
ddf.compute().describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  3.066766e+06                     3066766                     3066766
# mean   1.730215e+00  2023-01-17 00:22:26.288164  2023-01-17 00:38:06.427874
# min    1.000000e+00         2008-12-31 23:01:42         2009-01-01 14:29:11
# 25%    1.000000e+00  2023-01-09 16:21:57.250000         2023-01-09 16:37:06
# 50%    2.000000e+00  2023-01-17 08:42:29.500000  2023-01-17 08:58:30.500000
# 75%    2.000000e+00         2023-01-24 16:26:27         2023-01-24 16:42:49
# max    2.000000e+00         2023-02-01 00:56:53         2023-02-02 09:28:47
# std    4.438480e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.995023e+06   3.066766e+06  2.995023e+06  3.066766e+06
# mean      1.362532e+00   3.847342e+00  1.497440e+00  1.663980e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
ddf.compute().describe().T
# Out:
#                            count                        mean  \
# VendorID               3066766.0                    1.730215
# tpep_pickup_datetime     3066766  2023-01-17 00:22:26.288164
# tpep_dropoff_datetime    3066766  2023-01-17 00:38:06.427874
# passenger_count        2995023.0                    1.362532
# trip_distance          3066766.0                    3.847342
# RatecodeID             2995023.0                     1.49744
# PULocationID           3066766.0                  166.398046
# DOLocationID           3066766.0                  164.392631
# payment_type           3066766.0                    1.194483
# fare_amount            3066766.0                   18.367069
# extra                  3066766.0                    1.537842
# mta_tax                3066766.0                     0.48829
# tip_amount             3066766.0                    3.367941
# tolls_amount           3066766.0                    0.518491
# ...

# %%
ddf.compute().columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
# We just need 'VendorID','tpep_pickup_datetime','passenger_count' this three columns for this project

# %%
resample = ddf.resample('H').agg({'passenger_count': 'sum','fare_amount':'median', 'VendorID': 'count'})
resample.compute()
# Out:
#                       passenger_count  fare_amount  VendorID
# tpep_pickup_datetime
# 2008-12-31 23:00:00               2.0        35.00         2
# 2009-01-01 00:00:00               0.0          NaN         0
# 2009-01-01 01:00:00               0.0          NaN         0
# 2009-01-01 02:00:00               0.0          NaN         0
# 2009-01-01 03:00:00               0.0          NaN         0
# ...                               ...          ...       ...
# 2023-01-31 20:00:00            7871.0        12.10      6163
# 2023-01-31 21:00:00            8002.0        12.80      6223
# 2023-01-31 22:00:00            6759.0        12.80      5127
# 2023-01-31 23:00:00            3960.0        13.50      3041
# 2023-02-01 00:00:00              16.0        13.85        10
#
# [123458 rows x 3 columns]

# %%
resample.rename(columns={'passenger_count': 'passenger_demand','VendorID': 'taxi_demand'}).compute()
# Out:
#                       passenger_demand  fare_amount  taxi_demand
# tpep_pickup_datetime
# 2008-12-31 23:00:00                2.0        35.00            2
# 2009-01-01 00:00:00                0.0          NaN            0
# 2009-01-01 01:00:00                0.0          NaN            0
# 2009-01-01 02:00:00                0.0          NaN            0
# 2009-01-01 03:00:00                0.0          NaN            0
# ...                                ...          ...          ...
# 2023-01-31 20:00:00             7871.0        12.10         6163
# 2023-01-31 21:00:00             8002.0        12.80         6223
# 2023-01-31 22:00:00             6759.0        12.80         5127
# 2023-01-31 23:00:00             3960.0        13.50         3041
# 2023-02-01 00:00:00               16.0        13.85           10
#
# [123458 rows x 3 columns]

# %% [markdown]
# # Optimize For Memory

# %%
! ls -lrt C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/*.parquet | wc -l
# Out:
# 9

# %%
! ls C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/*.parquet
# Out:
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/July_2023-07.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/april_2023-04.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/august_2023-08.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/february_2023-02.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/january_2023-01.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/june_2023-06.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/march_2023-03.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/may_2023-05.parquet
# C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/september_2023-09.parquet

# %%
##### Create Cluster ##########

# %%
cluster = LocalCluster(
    name='timeseries',
    n_workers=2,
    threads_per_worker=1,
    host='localhost',
    scheduler_port=8786,
    asynchronous=True, 
    processes=False
)
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:51187' processes=4 threads=4, memory=7.88 GiB>

# %%
############## Steps ####################

# %%
def optimeToFitMemory(ddf):
    new_types = dict(
        int32 = ['passenger_count',],
        int16 = ['VendorID',]
    )
    for key in new_types:
        for col in new_types[key]:
            ddf[col] = ddf[col].astype(key)
    return ddf

# %%
ddf = dd.read_parquet('C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/january_2023-01.parquet', npartitions=4)
s1 = ddf.loc[
    ddf.tpep_pickup_datetime>'2021-12-31 23:00:00', 
    ['tpep_pickup_datetime','passenger_count', 'VendorID']
]
s2 = s1.set_index('tpep_pickup_datetime', sorted=True)
s3 = s2.ffill()
s4 = s3.resample('H').agg({'passenger_count': 'sum', 'VendorID': 'count'})
s5 = s4.map_partitions(optimeToFitMemory)
s6 = s5.reset_index()
s6.to_parquet('C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023.parquet', append=True, ignore_divisions=True)

# %%
s6.dask
# Out:
# HighLevelGraph with 12 layers.
# ...
#  0. read-parquet-73d70bf41b59931fb9f07cf45ccb575d
#  1. getitem-2c227a918c158fca6cc5b86f37230f9a
#  2. gt-51169c441e136473935ffe19807fa5b8
#  3. loc-series-8361e2bbd7578deff47a472ed1b5da7f
#  4. set_index-87a5ec91fba1912e6c130c187bac3b87
#  5. fillna-chunk-0792ba6bb6ca0fafc78a0f63ed7ed116
#  6. overlap-concat-01d3604381e8ce466d2c1b3443a69160
#  7. overlap-ffill-f3bd947f9453ac142de95b8bab6cdaed
#  8. repartition-merge-93d501e844ea4e350011427f662eba84
#  9. resample-a5a5c33c5c804e68efc16b80523c4070
#  10. optimeToFitMemory-a8c5002af6467c47ae78b083aaf9aeab
#  11. reset_index-62ff41434568e7f57603e6d51bf13ca6

# %%
files = [
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/april_2023-04.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/august_2023-08.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/september_2023-09.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/february_2023-02.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/january_2023-01.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/july_2023-07.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/june_2023-06.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/march_2023-03.parquet',
    'C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023/may_2023-05.parquet',
]

# %%
optimized_df = pd.DataFrame(
    {
        'tpep_pickup_datetime': [pd.Timestamp(year=2022, month=1, day=1, hour=0, minute=0, second=0)],
        'passenger_count':[0,],
        'VendorID': [0,]
    }
)


for file in files:
    ddf = dd.read_parquet(file, npartitions=100)
    s1 = ddf.loc[
        ddf.tpep_pickup_datetime >= '2022-01-01 00:00:00', 
        ['tpep_pickup_datetime','passenger_count', 'VendorID']
    ]
    s2 = s1.set_index('tpep_pickup_datetime', sorted=True)
    s3 = s2.ffill()
    s4 = s3.resample('H').agg({'passenger_count': 'sum', 'VendorID': 'count'})
    s5 = s4.map_partitions(optimeToFitMemory)
    s6 = s5.reset_index()
    optimized_df = pd.concat([optimized_df, s6.compute()], axis=0, ignore_index=True)

# %%
optimized_df.shape
# Out:
# (12889, 3)

# %%
# Rename desired columns name

# %%
optimized_df.rename(columns={'passenger_count': 'passenger_demand','VendorID': 'taxi_demand'}, inplace=True)

# %%
optimized_df.head()
# Out:
#   tpep_pickup_datetime  passenger_demand  taxi_demand
# 0  2022-01-01 00:00:00                 0            0
# 1  2023-03-31 16:00:00                 7            7
# 2  2023-03-31 17:00:00                 0            0
# 3  2023-03-31 18:00:00                 0            0
# 4  2023-03-31 19:00:00                 0            0

# %%
optimized_df.tail()
# Out:
#       tpep_pickup_datetime  passenger_demand  taxi_demand
# 12884  2023-09-05 14:00:00                 0            0
# 12885  2023-09-05 15:00:00                 0            0
# 12886  2023-09-05 16:00:00                 0            0
# 12887  2023-09-05 17:00:00                 0            0
# 12888  2023-09-05 18:00:00                 1            1

# %%
optimized_df.isnull().sum()
# Out:
# tpep_pickup_datetime    0
# passenger_demand        0
# taxi_demand             0
# dtype: int64

# %%
optimized_df.drop([0, 12888], inplace=True)

# %% [markdown]
# # Save The Data

# %%
optimized_df.to_csv('C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023.csv', index=False)

# %%
# Check The data that is it okay or not

# %%
pd.read_csv('C:/Users/SRA/Desktop/backup/C/MLgrit/time_series_project/uber-taxi-demand/data/2023.csv', encoding='unicode_escape')
# Out:
#       tpep_pickup_datetime  passenger_demand  taxi_demand
# 0      2023-03-31 16:00:00                 7            7
# 1      2023-03-31 17:00:00                 0            0
# 2      2023-03-31 18:00:00                 0            0
# 3      2023-03-31 19:00:00                 0            0
# 4      2023-03-31 20:00:00                 0            0
# ...                    ...               ...          ...
# 12882  2023-09-05 13:00:00                 0            0
# 12883  2023-09-05 14:00:00                 0            0
# 12884  2023-09-05 15:00:00                 0            0
# 12885  2023-09-05 16:00:00                 0            0
# 12886  2023-09-05 17:00:00                 0            0
#
# [12887 rows x 3 columns]
# 2024-01-04 14:56:14,891 - distributed.scheduler - WARNING - Worker failed to heartbeat within 300 seconds. Closing: <WorkerState 'tcp://127.0.0.1:51206', name: 1, status: running, memory: 0, processing: 0>
# ...
